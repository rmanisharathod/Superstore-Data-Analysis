# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Ensure plots are displayed in Jupyter Notebook
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('Sample - Superstore.csv', encoding='unicode_escape')

# %%
df.shape
# Out:
# (4578, 21)

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4578 entries, 0 to 4577
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         4578 non-null   int64
#  1   Order ID       4578 non-null   object
#  2   Order Date     4578 non-null   datetime64[ns]
#  3   Ship Date      4578 non-null   datetime64[ns]
#  4   Ship Mode      4578 non-null   object
#  5   Customer ID    4578 non-null   object
#  6   Customer Name  4578 non-null   object
#  7   Segment        4578 non-null   object
#  8   Country        4578 non-null   object
#  9   City           4578 non-null   object
#  10  State          4578 non-null   object
#  11  Postal Code    4578 non-null   int64
#  12  Region         4578 non-null   object
#  13  Product ID     4578 non-null   object
#  14  Category       4578 non-null   object
#  15  Sub-Category   4578 non-null   object
#  16  Product Name   4578 non-null   object
# ...

# %%
pd.isnull(df)
# Out:
#       Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0      False     False       False      False      False        False
# 1      False     False       False      False      False        False
# 2      False     False       False      False      False        False
# 3      False     False       False      False      False        False
# 4      False     False       False      False      False        False
# ...      ...       ...         ...        ...        ...          ...
# 4573   False     False       False      False      False        False
# 4574   False     False       False      False      False        False
# 4575   False     False       False      False      False        False
# 4576   False     False       False      False      False        False
# 4577   False     False       False      False      False        False
#
#       Customer Name  Segment  Country   City  ...  Postal Code  Region  \
# ...

# %%
 pd.isnull(df).sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  4578.000000   4578.000000   4578.000000  4578.000000  4578.000000
# mean   2289.500000  54879.289646    232.425959     3.802315     0.156686
# std    1321.699096  31767.037835    650.125232     2.245579     0.206231
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    1145.250000  22920.750000     16.768000     2.000000     0.000000
# 50%    2289.500000  55122.000000     52.728000     3.000000     0.200000
# 75%    3433.750000  90004.000000    213.394000     5.000000     0.200000
# max    4578.000000  99207.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  4578.000000
# mean     26.212476
# std     211.017604
# min   -3839.990400
# 25%       1.747800
# 50%       8.713900
# 75%      28.847950
# max    5039.985600

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Sales']
# Out:
# 0       261.9600
# 1       731.9400
# 2        14.6200
# 3       957.5775
# 4        22.3680
#           ...
# 4573    657.9300
# 4574     33.4800
# 4575     13.9000
# 4576     26.8600
# 4577      9.5840
# Name: Sales, Length: 4578, dtype: float64

# %%
# plotting code
sns.histplot(data=df, x='Sales')

# Show the plot
plt.show()

# %%
# plotting code
sns.boxplot(data=df, x='Sales')

# Show the plot
plt.show()

# %%
sdf = df[df['Sales'] < 2200]
sns.boxplot(data=sdf, x='Sales')
plt.show()

# %%
sns.histplot(data=sdf,x='Sales')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data=sdf,x='Sales')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data=sdf, x='Sales', bins=100)
plt.show()

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
#Total Sales, Profit, and Quantity Overview

df[['Sales', 'Profit', 'Quantity']].sum()
# Out:
# Sales       1.064046e+06
# Profit      1.200007e+05
# Quantity    1.740700e+04
# dtype: float64

# %%
# Changing the 'Order Date' and Ship date in datetime format

df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Order Date'])

# %%
# Default style

sns.set_theme(style="whitegrid")

# %%
# Total Sales, Profit, and Quantity Overview (Bar Chart)

summary = df[['Sales', 'Profit', 'Quantity']].sum()
summary.plot(kind='bar', color=['blue', 'green', 'orange'])
plt.title("Total Sales, Profit, and Quantity Overview")
plt.ylabel("Total Value")
plt.xticks(rotation=0)
plt.show()

# %%
# Top 10 Most Profitable Products

df.groupby('Product Name')['Profit'].sum().nlargest(10)
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          8959.9744
# Ibico EPK-21 Electric Binding System                                           4630.4755
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    2414.8810
# Ativa V4110MDD Micro-Cut Shredder                                              2400.9657
# 3D Systems Cube Printer, 2nd Generation, Magenta                               2365.9818
# Canon Imageclass D680 Copier / Fax                                             2169.9690
# Canon imageCLASS MF7460 Monochrome Digital Laser Multifunction Copier          1995.9900
# Plantronics Savi W720 Multi-Device Wireless Headset System                     1907.2140
# Razer Tiamat Over Ear 7.1 Surround Sound PC Gaming Headset                     1805.9097
# Fellowes PB300 Plastic Comb Binding Machine                                    1773.1143
# Name: Profit, dtype: float64

# %%
# Top 10 Most Profitable Products (Horizontal Bar Chart)

top_profitable = df.groupby('Product Name')['Profit'].sum().nlargest(10)
top_profitable.plot(kind='barh', color='green')
plt.title("Top 10 Most Profitable Products")
plt.xlabel("Total Profit")
plt.ylabel("Product Name")
plt.show()

# %%
# Top 10 Least Profitable (or Loss-Making) Products

df.groupby('Product Name')['Profit'].sum().nsmallest(10)
# Out:
# Product Name
# Lexmark MX611dhe Monochrome Laser Printer                       -4589.9730
# Cubify CubeX 3D Printer Triple Head Print                       -3839.9904
# Cubify CubeX 3D Printer Double Head Print                       -2279.9924
# Riverside Palais Royal Lawyers Bookcase, Royale Cherry Finish   -1982.2050
# Cisco TelePresence System EX90 Videoconferencing Unit           -1811.0784
# GBC DocuBind P400 Electric Binding System                       -1742.0672
# Martin Yale Chadless Opener Electric Letter Opener              -1382.4646
# GBC Ibimaster 500 Manual ProClick Binding System                -1369.7640
# Bush Advantage Collection Racetrack Conference Table            -1281.1142
# HP Designjet T520 Inkjet Large Format Printer - 24" Color        -944.9946
# Name: Profit, dtype: float64

# %%
# Top 10 Least Profitable (or Loss-Making) Products (Horizontal Bar Chart)

least_profitable = df.groupby('Product Name')['Profit'].sum().nsmallest(10)
least_profitable.plot(kind='barh', color='red')
plt.title("Top 10 Least Profitable Products")
plt.xlabel("Total Profit")
plt.ylabel("Product Name")
plt.show()

# %%
# Most Sold Product Categories

df['Category'].value_counts()
# Out:
# Category
# Office Supplies    2774
# Furniture           957
# Technology          847
# Name: count, dtype: int64

# %%
# Most Sold Product Categories (Bar Chart)

category_sales = df.groupby('Category')['Sales'].sum().sort_values(ascending=False)
category_sales.plot(kind='bar', color=['blue', 'orange', 'green'])
plt.title("Sales by Category")
plt.ylabel("Total Sales")
plt.xticks(rotation=0)
plt.show()

# %%
# Customer Segments with Highest Sales

df.groupby('Segment')['Sales'].sum().sort_values(ascending=False)
# Out:
# Segment
# Consumer       539090.0619
# Corporate      306219.2045
# Home Office    218736.7755
# Name: Sales, dtype: float64

# %%
# Customer Segments with Highest Sales (Bar Chart)

segment_sales = df.groupby('Segment')['Sales'].sum()
segment_sales.plot(kind='bar', color=['blue', 'orange', 'green'])
plt.title("Sales by Customer Segment")
plt.ylabel("Total Sales")
plt.xticks(rotation=0)
plt.show()

# %%
# Regional Sales Performance

df.groupby('Region')['Sales'].sum().sort_values(ascending=False)
# Out:
# Region
# West       329684.4745
# East       306833.5790
# Central    230987.6244
# South      196540.3640
# Name: Sales, dtype: float64

# %%
# Regional Sales Performance (Bar Chart)

regional_sales = df.groupby('Region')['Sales'].sum().sort_values(ascending=False)
regional_sales.plot(kind='bar', color='purple')
plt.title("Total Sales by Region")
plt.ylabel("Total Sales")
plt.xticks(rotation=0)
plt.show()

# %%
# Impact of Discount on Profit (Scatter Plot)

sns.scatterplot(data=df, x='Discount', y='Profit')
plt.title("Discount vs Profit")
plt.show()

# %%
# Impact of Discount on Profit (Scatter Plot)

plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='Discount', y='Profit', alpha=0.5, color='red')
plt.title("Discount vs Profit")
plt.xlabel("Discount")
plt.ylabel("Profit")
plt.show()

# %%
# Monthly Sales Trends (Line Chart)

# Set index and resample using 'ME' instead of 'M'
df.set_index('Order Date')['Sales'].resample('ME').sum().plot(figsize=(12,6), title="Monthly Sales Trends")

# Show the plot
plt.show()

# %%
# Monthly Sales Trends (Line Chart)

# Set index and resample using 'ME' instead of 'M'
monthly_sales = df.set_index('Order Date')['Sales'].resample('ME').sum()

# Plot the monthly sales trend
plt.figure(figsize=(12,6))
sns.lineplot(data=monthly_sales, marker='o', color='blue')
plt.title("Monthly Sales Trends")
plt.xlabel("Date")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(True)  # Add grid for better visualization
plt.show()

# %%
# Most Frequent Customers

df['Customer Name'].value_counts().head(10)
# Out:
# Customer Name
# Brian Moss           23
# Paul Prost           21
# Zuschuss Carroll     21
# Arthur Prichep       20
# Stefania Perrino     20
# Joel Eaton           20
# Russell Applegate    19
# Emily Phan           19
# Sanjit Chand         19
# Steve Nguyen         19
# Name: count, dtype: int64

# %%
# Most Frequent Customers (Bar Chart)

top_customers = df['Customer Name'].value_counts().head(10)
top_customers.plot(kind='barh', color='darkblue')
plt.title("Top 10 Most Frequent Customers")
plt.xlabel("Number of Orders")
plt.ylabel("Customer Name")
plt.show()

# %%
# Average Order Value (AOV)

df['Sales'].mean()
# Out:
# 232.42595934906075

# %%
# Average Order Value (AOV)

aov = df['Sales'].mean()
plt.figure(figsize=(5,5))
plt.bar(["Avg Order Value"], [aov], color='teal')
plt.title("Average Order Value (AOV)")
plt.ylabel("Sales ($)")
plt.show()
